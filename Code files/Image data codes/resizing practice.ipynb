# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import PIL

# %%
datapath = '/content/drive/MyDrive/Masters Project/Dataset/mfcc/processed/'

# %%
image = PIL.Image.open(datapath)

# %%
image.size
# Out:
# (360, 216)

# %%
import os
sizes = []
for (dirPath, dirName, filenames) in os.walk(datapath):
    for filename in filenames:
        image = PIL.Image.open(dirPath+filename)
        sizes.append(image.size)

# %%
print(sizes)
# Out:
# [(360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216), (360, 216)]

# %%
datapath = '/content/drive/MyDrive/Masters Project/Dataset/spectrograms/processed/'

# %%
sizes = []
for (dirPath, dirName, filenames) in os.walk(datapath):
    for filename in filenames:
        image = PIL.Image.open(dirPath+filename)
        tf.image.resize(image, )
        sizes.append(image.size)

# %%
print(sizes)
# Out:
# [(432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288), (432, 288)]

# %%
image = tf.keras.preprocessing.image.load_img('/content/drive/MyDrive/Masters Project/Dataset/mfcc/processed/Baramulla_07062021155339343323.png')

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=360x216 at 0x7F78997DC890>

# %%
newHeight = 32
newWidth = newHeight / image.height + image.width

# %%
supposeWidth = 32

# %%
newWidth
# Out:
# 360.14814814814815

# %%
newImage = image.resize((128, 128))
plt.margins(0,0)
newImage.save("/content/drive/MyDrive/samplesample.jpg", bbox_inches = 'tight',
    pad_inches = 0)

# %%
imageResize = tf.image.resize(imageArray, [128,128], preserve_aspect_ratio=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(imageResize.numpy().astype("uint8"))
plt.axis('off')
plt.savefig(f"/content/drive/MyDrive/Masters Project/Dataset/sample.jpeg")
plt.close()

# %%
def compressMe(verbose = False):
    
   
    picture = PIL.Image.open('/content/drive/MyDrive/Masters Project/Dataset/mfcc/processed/Baramulla_07062021155339343323.png')
      
    picture.save("/content/drive/MyDrive/Masters Project/Dataset/Compressed_sample2." 
                 "png", 
                 optimize = True, 
                 quality = 40)
    return

# %%
compressMe()

# %%
image.size
# Out:
# (360, 216)

# %%
imageArray = tf.keras.preprocessing.image.img_to_array(image)

# %%
imageArray
# Out:
# array([[[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        ...,
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow
image = imread('/content/drive/MyDrive/Masters Project/Dataset/mfcc/Baramulla_09062021145152815592.png')
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
image.shape
# Out:
# (50, 51, 4)

# %%
image.size
# Out:
# 10200

# %%
plt.axis('off')
imshow(image)

# %%
image
# Out:
# array([[[245, 123,  23, 255],
#         [245, 123,  23, 255],
#         [246, 126,  20, 255],
#         ...,
#         [245, 125,  21, 255],
#         [246, 126,  20, 255],
#         [247, 130,  18, 255]],
#
#        [[248, 135,  14, 255],
#         [248, 135,  14, 255],
#         [248, 135,  14, 255],
#         ...,
#         [247, 132,  16, 255],
#         [248, 133,  15, 255],
#         [246, 128,  19, 255]],
#
#        [[246, 128,  19, 255],
#         [247, 130,  18, 255],
#         [248, 133,  15, 255],
#         ...,
#         [246, 126,  20, 255],
#         [246, 128,  19, 255],
#         [246, 128,  19, 255]],
#
#        ...,
#
#        [[ 59,   9, 100, 255],
#         [ 61,   9, 101, 255],
#         [ 28,  12,  67, 255],
#         ...,
#         [ 27,  12,  65, 255],
#         [  8,   5,  29, 255],
#         [  4,   3,  20, 255]],
#
#        [[ 59,   9, 100, 255],
#         [ 61,   9, 101, 255],
#         [ 28,  12,  67, 255],
#         ...,
#         [ 27,  12,  65, 255],
# ...

# %%
import tensorflow as tf
image2 = tf.keras.preprocessing.image.load_img('/content/drive/MyDrive/Masters Project/Dataset/mfcc/Baramulla_09062021145152815592.png')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
type(image2)
# Out:
# PIL.Image.Image

# %%
tfImageArray = tf.keras.preprocessing.image.img_to_array(image2)

# %%
tfImageArray
# Out:
# array([[[245., 123.,  23.],
#         [245., 123.,  23.],
#         [246., 126.,  20.],
#         ...,
#         [245., 125.,  21.],
#         [246., 126.,  20.],
#         [247., 130.,  18.]],
#
#        [[248., 135.,  14.],
#         [248., 135.,  14.],
#         [248., 135.,  14.],
#         ...,
#         [247., 132.,  16.],
#         [248., 133.,  15.],
#         [246., 128.,  19.]],
#
#        [[246., 128.,  19.],
#         [247., 130.,  18.],
#         [248., 133.,  15.],
#         ...,
#         [246., 126.,  20.],
#         [246., 128.,  19.],
#         [246., 128.,  19.]],
#
#        ...,
#
#        [[ 59.,   9., 100.],
#         [ 61.,   9., 101.],
#         [ 28.,  12.,  67.],
#         ...,
#         [ 27.,  12.,  65.],
#         [  8.,   5.,  29.],
#         [  4.,   3.,  20.]],
#
#        [[ 59.,   9., 100.],
#         [ 61.,   9., 101.],
#         [ 28.,  12.,  67.],
#         ...,
#         [ 27.,  12.,  65.],
#         [  8.,   5.,  29.],
# ...

# %%
tfImageArray.shape
# Out:
# (50, 51, 3)

# %%
tfImageArray.shape
imshow(np.concatenate(tfImageArray, [255]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-36f71c3cf3af> in <module>()
#       1 tfImageArray.shape
# ----> 2 imshow(np.concatenate(tfImageArray, [255]))
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
np.c_[tfImageArray+[255]]
# Out:
# array([[[500., 378., 278.],
#         [500., 378., 278.],
#         [501., 381., 275.],
#         ...,
#         [500., 380., 276.],
#         [501., 381., 275.],
#         [502., 385., 273.]],
#
#        [[503., 390., 269.],
#         [503., 390., 269.],
#         [503., 390., 269.],
#         ...,
#         [502., 387., 271.],
#         [503., 388., 270.],
#         [501., 383., 274.]],
#
#        [[501., 383., 274.],
#         [502., 385., 273.],
#         [503., 388., 270.],
#         ...,
#         [501., 381., 275.],
#         [501., 383., 274.],
#         [501., 383., 274.]],
#
#        ...,
#
#        [[314., 264., 355.],
#         [316., 264., 356.],
#         [283., 267., 322.],
#         ...,
#         [282., 267., 320.],
#         [263., 260., 284.],
#         [259., 258., 275.]],
#
#        [[314., 264., 355.],
#         [316., 264., 356.],
#         [283., 267., 322.],
#         ...,
#         [282., 267., 320.],
#         [263., 260., 284.],
# ...

# %%
input_arr = np.array([tfImageArray], dtype='uint8')

# %%
input_arr
# Out:
# array([[[[245, 123,  23],
#          [245, 123,  23],
#          [246, 126,  20],
#          ...,
#          [245, 125,  21],
#          [246, 126,  20],
#          [247, 130,  18]],
#
#         [[248, 135,  14],
#          [248, 135,  14],
#          [248, 135,  14],
#          ...,
#          [247, 132,  16],
#          [248, 133,  15],
#          [246, 128,  19]],
#
#         [[246, 128,  19],
#          [247, 130,  18],
#          [248, 133,  15],
#          ...,
#          [246, 126,  20],
#          [246, 128,  19],
#          [246, 128,  19]],
#
#         ...,
#
#         [[ 59,   9, 100],
#          [ 61,   9, 101],
#          [ 28,  12,  67],
#          ...,
#          [ 27,  12,  65],
#          [  8,   5,  29],
#          [  4,   3,  20]],
#
#         [[ 59,   9, 100],
#          [ 61,   9, 101],
#          [ 28,  12,  67],
#          ...,
#          [ 27,  12,  65],
#          [  8,   5,  29],
#          [  4,   3,  20]],
#
#         [[ 59,   9, 100],
# ...

# %%
imshow(input_arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c0217a00eb5b> in <module>()
# ----> 1 imshow(input_arr)
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/_io.py in imshow(arr, plugin, **plugin_args)
#     152     if isinstance(arr, str):
#     153         arr = call_plugin('imread', arr, plugin=plugin)
# --> 154     return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
#     155
#     156
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     208                                (plugin, kind))
#     209
# --> 210     return func(*args, **kwargs)
#     211
#     212
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/_plugins/matplotlib_plugin.py in imshow(image, ax, show_cbar, **kwargs)
#     156
#     157     ax = ax or plt.gca()
# --> 158     ax_im = ax.imshow(image, **kwargs)
# ...

# %%
im = tf.keras.preprocessing.image.array_to_img(tfImageArray)

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=51x50 at 0x7EFED4FE2490>
